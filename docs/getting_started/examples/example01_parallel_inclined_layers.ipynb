# %% [markdown]
# # Example 1 - Parallel Inclined Layers
#
# This example will show how to convert the geological map below to a `GemPy` model. This example is based on digitized data. The area is 972 m wide (W-E extent) and 1069 m high (N-S extent).
# <img src="../images/task1.png" width="300">

# %% [markdown]
# ## Importing Libraries

# %%
import sys
sys.path.append('../../../../gemgis')
import gemgis as gg
import geopandas as gpd
import rasterio
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from mpl_toolkits.axes_grid1 import make_axes_locatable
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\ale93371\Anaconda3\envs\test_gempy\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# ## Loading Data

# %%
base_map = rasterio.open('../../../../gemgis_data/data/example01_parallel_inclined_layers/task1.tif')
interfaces = gpd.read_file('../../../../gemgis_data/data/example01_parallel_inclined_layers/interfaces1_lines.shp')
orientations = gpd.read_file('../../../../gemgis_data/data/example01_parallel_inclined_layers/orientations1.shp')
extent = gpd.read_file('../../../../gemgis_data/data/example01_parallel_inclined_layers/extent1.shp')
geological_map = gpd.read_file('../../../../gemgis_data/data/example01_parallel_inclined_layers/geolmap1.shp')
topo = gpd.read_file('../../../../gemgis_data/data/example01_parallel_inclined_layers/topo1.shp')
custom_section = gpd.read_file('../../../../gemgis_data/data/example01_parallel_inclined_layers/customsections1.shp')

# %% [markdown]
# ## Inspect Data

# %%
interfaces.head()
# Out:
#      id formation                                           geometry
# 0  None     Sand1  LINESTRING (0.256 264.862, 10.593 276.734, 17....
# 1  None       Ton  LINESTRING (0.188 495.787, 8.841 504.142, 41.0...
# 2  None       Ton  LINESTRING (970.677 833.053, 959.372 800.023, ...

# %%
orientations.head()
# Out:
#      id formation   dip  azimuth                 geometry
# 0  None       Ton 30.50   180.00   POINT (96.471 451.564)
# 1  None       Ton 30.50   180.00  POINT (172.761 661.877)
# 2  None       Ton 30.50   180.00  POINT (383.074 957.758)
# 3  None       Ton 30.50   180.00  POINT (592.356 722.702)
# 4  None       Ton 30.50   180.00  POINT (766.586 348.469)

# %%
extent.head()
# Out:
#      id                                           geometry
# 0  None  POLYGON ((-0.000 1069.000, 972.000 1069.000, 9...

# %%
geological_map.head()
# Out:
#      id formation                                           geometry
# 0  None     Sand1  POLYGON ((0.256 264.862, 10.593 276.734, 17.13...
# 1  None       Ton  POLYGON ((0.256 264.862, 0.188 495.787, 8.841 ...
# 2  None     Sand2  POLYGON ((0.188 495.787, 0.249 1068.760, 278.5...
# 3  None     Sand2  POLYGON ((511.675 1068.852, 971.698 1068.800, ...

# %%
topo.head()
# Out:
#      id    Z                                           geometry
# 0  None  400  LINESTRING (0.741 475.441, 35.629 429.247, 77....
# 1  None  300  LINESTRING (645.965 0.525, 685.141 61.866, 724...
# 2  None  400  LINESTRING (490.292 0.525, 505.756 40.732, 519...
# 3  None  600  LINESTRING (911.433 1068.585, 908.856 1026.831...
# 4  None  700  LINESTRING (228.432 1068.585, 239.772 1017.037...

# %%
custom_section.head()
# Out:
#      id   section                                     geometry
# 0  None  Section1  LINESTRING (1.372 383.979, 970.995 383.883)

# %% [markdown]
# ## Create GemPy Data Class

# %%
geo_data = gg.GemPyData(model_name='Model1', 
                        crs='EPSG:4326')

# %%
vars(geo_data)
# Out:
# {'model_name': 'Model1',
#  'crs': 'EPSG:4326',
#  'extent': None,
#  'resolution': None,
#  'interfaces': None,
#  'orientations': None,
#  'section_dict': None,
#  'stack': None,
#  'dem': None,
#  'surface_colors': None,
#  'geolmap': None,
#  'basemap': None,
#  'faults': None,
#  'is_fault': None,
#  'raw_i': None,
#  'raw_o': None,
#  'raw_dem': None,
#  'slope': None,
#  'hillshades': None,
#  'aspect': None,
#  'wms': None,
#  'tectonics': None,
#  'customsections': None,
#  'contours': None}

# %% [markdown]
# ## Set Extent

# %%
geo_data.set_extent(gdf=extent, minz=300, maxz=800)
geo_data.extent
# Out:
# [-0.0, 972.0, -0.0, 1069.0, 300, 800]

# %% [markdown]
# ## Set Resolution

# %%
geo_data.set_resolution(50,50,50)
geo_data.resolution
# Out:
# [50, 50, 50]

# %% [markdown]
# ## Loading Layer Style

# %%
cols = gg.utils.load_surface_colors('../../../../gemgis_data/data/example01_parallel_inclined_layers/style1.qml', geological_map)
cols
# Out:
# ['#b35a2a', '#b35a2a', '#525252']

# %% [markdown]
# ## Attribute Data to Data Class

# %%
geo_data.set_extent(0,972,0,1069, 300, 800)
geo_data.extent
# Out:
# [0, 972, 0, 1069, 300, 800]

# %%
geo_data.raw_i = interfaces
geo_data.raw_i
# Out:
#      id formation                                           geometry
# 0  None     Sand1  LINESTRING (0.256 264.862, 10.593 276.734, 17....
# 1  None       Ton  LINESTRING (0.188 495.787, 8.841 504.142, 41.0...
# 2  None       Ton  LINESTRING (970.677 833.053, 959.372 800.023, ...

# %%
geo_data.raw_o = orientations
geo_data.raw_o
# Out:
#      id formation   dip  azimuth                 geometry
# 0  None       Ton 30.50   180.00   POINT (96.471 451.564)
# 1  None       Ton 30.50   180.00  POINT (172.761 661.877)
# 2  None       Ton 30.50   180.00  POINT (383.074 957.758)
# 3  None       Ton 30.50   180.00  POINT (592.356 722.702)
# 4  None       Ton 30.50   180.00  POINT (766.586 348.469)
# 5  None       Ton 30.50   180.00  POINT (843.907 167.023)
# 6  None       Ton 30.50   180.00  POINT (941.846 428.883)
# 7  None       Ton 30.50   180.00   POINT (22.142 299.553)

# %%
geo_data.basemap = base_map.read(1)
geo_data.basemap
# Out:
# array([[217, 229, 227, ..., 227, 233, 204],
#        [245, 254, 254, ..., 254, 254, 246],
#        [244, 254, 254, ..., 254, 254, 240],
#        ...,
#        [244, 254, 254, ..., 254, 254, 230],
#        [245, 254, 254, ..., 254, 254, 246],
#        [244, 254, 254, ..., 254, 254, 246]], dtype=uint8)

# %%
geo_data.geolmap = geological_map
geo_data.geolmap
# Out:
#      id formation                                           geometry
# 0  None     Sand1  POLYGON ((0.256 264.862, 10.593 276.734, 17.13...
# 1  None       Ton  POLYGON ((0.256 264.862, 0.188 495.787, 8.841 ...
# 2  None     Sand2  POLYGON ((0.188 495.787, 0.249 1068.760, 278.5...
# 3  None     Sand2  POLYGON ((511.675 1068.852, 971.698 1068.800, ...

# %%
geo_data.customsections = custom_section
geo_data.customsections
# Out:
#      id   section                                     geometry
# 0  None  Section1  LINESTRING (1.372 383.979, 970.995 383.883)

# %%
geo_data.contours = topo
geo_data.contours
# Out:
#      id    Z                                           geometry
# 0  None  400  LINESTRING (0.741 475.441, 35.629 429.247, 77....
# 1  None  300  LINESTRING (645.965 0.525, 685.141 61.866, 724...
# 2  None  400  LINESTRING (490.292 0.525, 505.756 40.732, 519...
# 3  None  600  LINESTRING (911.433 1068.585, 908.856 1026.831...
# 4  None  700  LINESTRING (228.432 1068.585, 239.772 1017.037...
# 5  None  600  LINESTRING (114.513 1068.069, 151.627 930.438,...
# 6  None  500  LINESTRING (28.429 1067.554, 71.728 866.004, 1...

# %% [markdown]
# ## Plot Data

# %%
gg.visualization.plot_data(geo_data, 
                           show_interfaces=True,
                           show_orientations=True,
                           show_basemap=True,
                           show_geolmap=True,
                           show_customsections=True,
                           show_contours=True,
                           cmap_interfaces='Spectral',
                           cmap_orientations='Spectral',
                           cmap_geolmap = cols, 
                           cmap_contours='gist_earth'
                           )
# Out:
# (<Figure size 1440x720 with 2 Axes>,
#  <AxesSubplot:xlabel='X', ylabel='Y'>,
#  <AxesSubplot:xlabel='X', ylabel='Y'>)

# %% [markdown]
# ## Interpolate Topography

# %%
dem = gg.vector.interpolate_raster(topo, method='rbf')
geo_data.raw_dem = dem
geo_data.raw_dem
# Out:
# array([[393.56371914, 393.50838517, 393.45386851, ..., 396.15856133,
#         398.11421775, 400.06334288],
#        [393.41982945, 393.36494644, 393.31088433, ..., 396.20694282,
#         398.16690286, 400.12027997],
#        [393.27639239, 393.22196212, 393.16835634, ..., 396.25151286,
#         398.21571981, 400.17329448],
#        ...,
#        [478.57227615, 479.19563116, 479.82905526, ..., 623.85302909,
#         624.30262569, 624.75277621],
#        [478.9113727 , 479.53431484, 480.1673209 , ..., 623.8870041 ,
#         624.33696638, 624.78749278],
#        [479.25569795, 479.87822832, 480.51081617, ..., 623.92447752,
#         624.37477606, 624.82564903]])

# %%
gg.visualization.plot_data(geo_data, 
                           show_interfaces=True,
                           show_orientations=True,
                           show_basemap=True,
                           show_topo=True,
                           cmap_interfaces='Spectral',
                           cmap_orientations='Spectral',
                           cmap_contours='gist_earth'
                           )
# Out:
# (<Figure size 1440x720 with 2 Axes>,
#  <AxesSubplot:xlabel='X', ylabel='Y'>,
#  <AxesSubplot:xlabel='X', ylabel='Y'>)

# %% [markdown]
# ## Save Topography as Raster

# %% [raw]
# gg.raster.save_as_tiff('../../../gemgis/data/example01_parallel_inclined_layers/topo.tif',np.flipud(dem), crs='EPSG:4326', extent=geo_data.extent)

# %%
topography = rasterio.open('../../../../gemgis_data/data/example01_parallel_inclined_layers/raster1.tif')
topography
# Out:
# <open DatasetReader name='../../../../gemgis_data/data/example01_parallel_inclined_layers/raster1.tif' mode='r'>

# %% [markdown]
# ## Set Interfaces

# %%
interfaces_coords = gg.vector.extract_xyz(interfaces,topography, reset_index=False)
interfaces_coords.head()
# Out:
#     formation                geometry     X      Y      Z
# 0 0     Sand1   POINT (0.256 264.862)  0.26 264.86 353.97
#   0     Sand1  POINT (10.593 276.734) 10.59 276.73 359.04
#   0     Sand1  POINT (17.135 289.090) 17.13 289.09 364.28
#   0     Sand1  POINT (19.150 293.313) 19.15 293.31 364.99
#   0     Sand1  POINT (27.795 310.572) 27.80 310.57 372.81

# %%
geo_data.to_gempy_df(interfaces_coords, 'interfaces')
geo_data.interfaces.head()
# Out:
#    level_0  level_1     X      Y      Z formation
# 0        0        0  0.26 264.86 353.97     Sand1
# 1        0        0 10.59 276.73 359.04     Sand1
# 2        0        0 17.13 289.09 364.28     Sand1
# 3        0        0 19.15 293.31 364.99     Sand1
# 4        0        0 27.80 310.57 372.81     Sand1

# %% [markdown]
# ## Set Orientations

# %%
orientations_coords = gg.vector.extract_xyz(orientations,dem,extent=geo_data.extent)
orientations_coords.head()
# Out:
#   formation   dip  azimuth                 geometry      X      Y      Z
# 0       Ton 30.50   180.00   POINT (96.471 451.564)  96.47 451.56 477.73
# 1       Ton 30.50   180.00  POINT (172.761 661.877) 172.76 661.88 481.73
# 2       Ton 30.50   180.00  POINT (383.074 957.758) 383.07 957.76 444.45
# 3       Ton 30.50   180.00  POINT (592.356 722.702) 592.36 722.70 480.57
# 4       Ton 30.50   180.00  POINT (766.586 348.469) 766.59 348.47 498.96

# %%
geo_data.to_gempy_df(orientations_coords, 'orientations')
geo_data.orientations.head()
# Out:
#    index      X      Y      Z formation   dip  azimuth  polarity
# 0      0  96.47 451.56 477.73       Ton 30.50   180.00         1
# 1      1 172.76 661.88 481.73       Ton 30.50   180.00         1
# 2      2 383.07 957.76 444.45       Ton 30.50   180.00         1
# 3      3 592.36 722.70 480.57       Ton 30.50   180.00         1
# 4      4 766.59 348.47 498.96       Ton 30.50   180.00         1

# %% [markdown]
# ## Check Data Class

# %%
vars(geo_data)
# Out:
# {'model_name': 'Model1',
#  'crs': 'EPSG:4326',
#  'extent': [0, 972, 0, 1069, 300, 800],
#  'resolution': [50, 50, 50],
#  'interfaces':      level_0  level_1      X       Y      Z formation
#  0          0        0   0.26  264.86 353.97     Sand1
#  1          0        0  10.59  276.73 359.04     Sand1
#  2          0        0  17.13  289.09 364.28     Sand1
#  3          0        0  19.15  293.31 364.99     Sand1
#  4          0        0  27.80  310.57 372.81     Sand1
#  ..       ...      ...    ...     ...    ...       ...
#  126        2        0 636.02  859.79 618.32       Ton
#  127        2        0 608.85  912.40 647.91       Ton
#  128        2        0 560.11  990.62 697.06       Ton
#  129        2        0 526.38 1045.39 724.56       Ton
#  130        2        0 512.24 1067.95 734.76       Ton
#
#  [131 rows x 6 columns],
#  'orientations':    index      X      Y      Z formation   dip  azimuth  polarity
#  0      0  96.47 451.56 477.73       Ton 30.50   180.00         1
#  1      1 172.76 661.88 481.73       Ton 30.50   180.00         1
#  2      2 383.07 957.76 444.45       Ton 30.50   180.00         1
#  3      3 592.36 722.70 480.57       Ton 30.50   180.00         1
#  4      4 766.59 348.47 498.96       Ton 30.50   180.00         1
#  5      5 843.91 167.02 537.82       Ton 30.50   180.00         1
#  6      6 941.85 428.88 511.96       Ton 30.50   180.00         1
#  7      7  22.14 299.55 446.66       Ton 30.50   180.00         1,
#  'section_dict': None,
#  'stack': None,
#  'dem': None,
#  'surface_colors': None,
#  'geolmap':      id formation                                           geometry
#  0  None     Sand1  POLYGON ((0.256 264.862, 10.593 276.734, 17.13...
#  1  None       Ton  POLYGON ((0.256 264.862, 0.188 495.787, 8.841 ...
#  2  None     Sand2  POLYGON ((0.188 495.787, 0.249 1068.760, 278.5...
#  3  None     Sand2  POLYGON ((511.675 1068.852, 971.698 1068.800, ...,
#  'basemap': array([[217, 229, 227, ..., 227, 233, 204],
#         [245, 254, 254, ..., 254, 254, 246],
#         [244, 254, 254, ..., 254, 254, 240],
#         ...,
#         [244, 254, 254, ..., 254, 254, 230],
#         [245, 254, 254, ..., 254, 254, 246],
#         [244, 254, 254, ..., 254, 254, 246]], dtype=uint8),
#  'faults': None,
#  'is_fault': None,
#  'raw_i':      id formation                                           geometry
#  0  None     Sand1  LINESTRING (0.256 264.862, 10.593 276.734, 17....
#  1  None       Ton  LINESTRING (0.188 495.787, 8.841 504.142, 41.0...
#  2  None       Ton  LINESTRING (970.677 833.053, 959.372 800.023, ...,
#  'raw_o':      id formation   dip  azimuth                 geometry
#  0  None       Ton 30.50   180.00   POINT (96.471 451.564)
#  1  None       Ton 30.50   180.00  POINT (172.761 661.877)
#  2  None       Ton 30.50   180.00  POINT (383.074 957.758)
#  3  None       Ton 30.50   180.00  POINT (592.356 722.702)
#  4  None       Ton 30.50   180.00  POINT (766.586 348.469)
#  5  None       Ton 30.50   180.00  POINT (843.907 167.023)
#  6  None       Ton 30.50   180.00  POINT (941.846 428.883)
#  7  None       Ton 30.50   180.00   POINT (22.142 299.553),
#  'raw_dem': array([[393.56371914, 393.50838517, 393.45386851, ..., 396.15856133,
#          398.11421775, 400.06334288],
#         [393.41982945, 393.36494644, 393.31088433, ..., 396.20694282,
#          398.16690286, 400.12027997],
#         [393.27639239, 393.22196212, 393.16835634, ..., 396.25151286,
#          398.21571981, 400.17329448],
#         ...,
#         [478.57227615, 479.19563116, 479.82905526, ..., 623.85302909,
#          624.30262569, 624.75277621],
#         [478.9113727 , 479.53431484, 480.1673209 , ..., 623.8870041 ,
#          624.33696638, 624.78749278],
#         [479.25569795, 479.87822832, 480.51081617, ..., 623.92447752,
#          624.37477606, 624.82564903]]),
#  'slope': None,
#  'hillshades': None,
#  'aspect': None,
#  'wms': None,
#  'tectonics': None,
#  'customsections':      id   section                                     geometry
#  0  None  Section1  LINESTRING (1.372 383.979, 970.995 383.883),
#  'contours':      id    Z                                           geometry
#  0  None  400  LINESTRING (0.741 475.441, 35.629 429.247, 77....
#  1  None  300  LINESTRING (645.965 0.525, 685.141 61.866, 724...
#  2  None  400  LINESTRING (490.292 0.525, 505.756 40.732, 519...
#  3  None  600  LINESTRING (911.433 1068.585, 908.856 1026.831...
#  4  None  700  LINESTRING (228.432 1068.585, 239.772 1017.037...
#  5  None  600  LINESTRING (114.513 1068.069, 151.627 930.438,...
#  6  None  500  LINESTRING (28.429 1067.554, 71.728 866.004, 1...,
#  'model_width': 972,
#  'model_length': 1069,
#  'model_depth': 500,
#  'model_area': 1039068,
#  'model_volume': 519534000,
#  'cell_width': 19.44,
#  'cell_length': 21.38,
#  'cell_depth': 10.0}

# %% [markdown]
# ## Add Section Dict

# %%
geo_data.to_section_dict(custom_section, 'section')
geo_data.section_dict
# Out:
# {'Section1': ([1.372395262185787, 383.9794474025771],
#   [970.9954955186289, 383.8831909730347],
#   [100, 80])}

# %% [markdown]
# ## Add Surface Colors

# %%
geo_data.to_surface_color_dict('../../../../gemgis_data/data/example01_parallel_inclined_layers/style1.qml', basement='Sand2')
geo_data.surface_colors
# Out:
# {'Sand1': '#b35a2a', 'Ton': '#525252', 'basement': '#b35a2a'}

# %% [markdown]
# ## Add Stack

# %%
geo_data.stack = {"Strat_Series": ('Sand1', 'Ton')}
geo_data.stack
# Out:
# {'Strat_Series': ('Sand1', 'Ton')}

# %% [markdown]
# ## Add DEM

# %%
geo_data.dem = '../../../../gemgis_data/data/example01_parallel_inclined_layers/raster1.tif'
geo_data.dem
# Out:
# '../../../../gemgis_data/data/example01_parallel_inclined_layers/raster1.tif'

# %% [markdown]
# ## Visualize Data Set
#
# Creating the topography mesh.

# %%
grid = gg.visualization.create_dem_3d(dem=dem, extent=[0,972,0,1069])

# %% [markdown]
# Creating the mesh for the contour lines of the topography.

# %%
contours = gg.visualization.create_lines_3d(gdf=topo)

# %% [markdown]
# Creating the mesh for the point data

# %%
interfaces_mesh = gg.visualization.create_points_3d(gdf=interfaces_coords)
orientations_mesh = gg.visualization.create_points_3d(gdf=orientations_coords)

# %%
import pyvista as pv
p = pv.Plotter(notebook =True)

p.add_mesh(mesh=grid, cmap = 'gist_earth')
p.add_mesh(mesh=contours, color='red')
p.add_mesh(mesh=interfaces_mesh, color='blue')
p.add_mesh(mesh=orientations_mesh, color='orange')

p.camera_position =[(-283.285811675846, -1597.1397046051004, 1155.542325449192), 
                    (577.9371599370799, 495.3480261506809, 381.7124055285182), 
                    (0.17313457304419916, 0.27814381639313923, 0.9448070898437746)]
p.set_background('white')
p.show_grid(color='black')
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x25C58F0D100>

# %% [markdown]
# ## Create GemPy Model

# %% [markdown]
# ### Importing GemPy
#
# Please see https://docs.gempy.org/installation.html for more information on how to install GemPy.

# %%
import sys  
sys.path.append('../../../../gempy-master')
import gempy as gp
print(gp)
print(gp.__version__)
# Out:
# <module 'gempy' from 'C:\\Users\\ale93371\\Anaconda3\\envs\\test_gempy\\lib\\site-packages\\gempy\\__init__.py'>
# 2.2.6

# %% [markdown]
# ### Creating GemPy Model
#
# For more information on how to create a GemPy Model, please see the tutorials at: https://docs.gempy.org/tutorials/index.html. With the attributes of the GemPy Data Class, all necessary variables can be passed to the model.

# %%
geo_model = gp.create_model(geo_data.model_name)
geo_model
# Out:
# Model1  2021-01-17 16:35

# %%
geo_model.solutions
# Out:
# Lithology ids
#   []

# %% [markdown]
# ### Initiating the Model

# %%
gp.init_data(geo_model, geo_data.extent, geo_data.resolution,
             surface_points_df = geo_data.interfaces,
             orientations_df = geo_data.orientations,
             default_values=True)
# Out:
# Active grids: ['regular']
# Model1  2021-01-17 16:35

# %%
geo_model.surfaces
# Out:
#   surface          series  order_surfaces    color  id
# 0   Sand1  Default series               1  #015482   1
# 1     Ton  Default series               2  #9f0052   2

# %% [markdown]
# ### Mapping the layer stack to surfaces

# %%
gp.map_stack_to_surfaces(geo_model,
                         geo_data.stack,
                         remove_unused_series=True)
geo_model.add_surfaces('basement')
# Out:
#     surface        series  order_surfaces    color  id
# 0     Sand1  Strat_Series               1  #015482   1
# 1       Ton  Strat_Series               2  #9f0052   2
# 2  basement  Strat_Series               3  #ffbe00   3

# %%
gg.utils.show_number_of_data_points(geo_model=geo_model)
# Out:
#     surface        series  order_surfaces    color  id  No. of Interfaces  No. of Orientations
# 0     Sand1  Strat_Series               1  #015482   1                 95                    0
# 1       Ton  Strat_Series               2  #9f0052   2                 36                    8
# 2  basement  Strat_Series               3  #ffbe00   3                  0                    0

# %% [markdown]
# ### Change surface colors

# %%
geo_model.surfaces.colors.change_colors(geo_data.surface_colors)

# %% [markdown]
# ### Load Topography

# %% [markdown]
# A raster created with ArcGIS has to be loaded as the import of the created raster fails. This is due to a bug in `GemPy`described here: https://github.com/cgre-aachen/gempy/issues/492

# %%
geo_model.set_topography(
    source='gdal', filepath='../../../../gemgis_data/data/example01_parallel_inclined_layers/raster1.tif')
# Out:
# Cropped raster to geo_model.grid.extent.
# depending on the size of the raster, this can take a while...
# storing converted file...
# Active grids: ['regular' 'topography']
# Grid Object. Values:
# array([[   9.72      ,   10.69      ,  305.        ],
#        [   9.72      ,   10.69      ,  315.        ],
#        [   9.72      ,   10.69      ,  325.        ],
#        ...,
#        [ 970.056     , 1059.28181818,  622.0892334 ],
#        [ 970.056     , 1063.16909091,  622.06713867],
#        [ 970.056     , 1067.05636364,  622.05786133]])

# %% [markdown]
# ### Set Custom Section Grid

# %%
geo_model.set_section_grid(geo_data.section_dict)
# Out:
# Active grids: ['regular' 'topography' 'sections']
#                                            start                                    stop resolution   dist
# Section1  [1.372395262185787, 383.9794474025771]  [970.9954955186289, 383.8831909730347]  [100, 80] 969.62

# %% [markdown]
# ### Plot Custom Section Traces

# %%
gp.plot.plot_section_traces(geo_model)

# %% [markdown]
# ### Set Interpolator

# %%
gp.set_interpolator(geo_model,
                    compile_theano=True,
                    theano_optimizer='fast_compile',
                    verbose=[],
                    update_kriging = False
                    )
# Out:
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                    values
# range            1528.90
# $C_o$           55655.83
# drift equations      [3]

# %% [markdown]
# ### Compute Model

# %% [raw]
# gp.compute_model?

# %%
sol = gp.compute_model(geo_model, compute_mesh=True)
# Out:
# C:\Users\ale93371\Anaconda3\envs\test_gempy\lib\site-packages\gempy\core\solution.py:128: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.geological_map = np.array([values[0][:, l0: l1], values[4][:, l0: l1].astype(float)])
# C:\Users\ale93371\Anaconda3\envs\test_gempy\lib\site-packages\gempy\core\solution.py:132: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   self.sections = np.array([values[0][:, l0: l1], values[4][:, l0: l1].astype(float)])

# %%
import numpy as np

file_path ='../../../../gemgis_data/data/example01_parallel_inclined_layers/'
np.save(file_path + 'lith_block', sol.lith_block)

# %%
geo_model.surfaces.df
# Out:
#     surface        series  order_surfaces  isBasement isFault  isActive  \
# 0     Sand1  Strat_Series               1       False   False      True
# 1       Ton  Strat_Series               2       False   False      True
# 2  basement  Strat_Series               3        True   False      True
#
#    hasData    color                                           vertices  \
# 0     True  #b35a2a  [[29.160000000000004, 194.27877317428587, 305....
# 1     True  #525252  [[29.160000000000004, 365.78652999877926, 305....
# 2     True  #b35a2a                                                NaN
#
#                                                edges sfai  id  \
# 0  [[2, 1, 0], [2, 0, 3], [3, 4, 2], [2, 4, 5], [... 0.26   1
# 1  [[2, 1, 0], [2, 0, 3], [3, 4, 2], [2, 4, 5], [... 0.21   2
# 2                                                NaN  NaN   3
#
#    No. of Interfaces  No. of Orientations
# 0                 95                    0
# 1                 36                    8
# 2                  0                    0

# %% [markdown]
# ### Plot Geological Map

# %% [markdown]
# The geological map had to be created manually as there seems to be a bug when creating the geological map with `GemGIS`. This was reported already: https://github.com/cgre-aachen/gempy/issues/446

# %% [raw]
# gp.plot_2d(geo_model, section_names=['topography'], show_contours=False)

# %% [raw]
# shape = geo_model._grid.topography.values_2d[:, :, 2].shape
# geolmap = geo_model.solutions.geological_map[0].reshape(shape)
# cols = ['#b35a2a','#525252','#b35a2a' ]
# plt.figure(figsize=(10,10))
# plt.imshow(np.flipud(base_map.read(1)), origin = 'lower', cmap ='gray')
# gmap = np.rot90(geolmap,1)
# plt.imshow(gmap, extent=geo_data.extent[:4], alpha=0.75, cmap=ListedColormap(cols))

# %% [markdown]
# ### Plotting Cross Sections

# %%
gp.plot_2d(geo_model, section_names=['Section1'], show_topography=True)
# Out:
# C:\Users\ale93371\Anaconda3\envs\test_gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %%
gp.plot_2d(geo_model, direction='x', show_topography=True)
# Out:
# C:\Users\ale93371\Anaconda3\envs\test_gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %%
gp.plot_2d(geo_model, direction='x', show_topography=True, cell_number=25)
# Out:
# C:\Users\ale93371\Anaconda3\envs\test_gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %%
gp.plot_2d(geo_model, direction='y', show_topography=True)
# Out:
# C:\Users\ale93371\Anaconda3\envs\test_gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %% [markdown]
# ### Plotting 3D model

# %%
gpv = gp.plot_3d(geo_model, image=False, show_topography=True,
                 plotter_type='basic', notebook=True, show_lith=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x25C68A59E20>

# %% [markdown]
# ## Postprocessing - Converting Geological Map to Shape Files

# %% [markdown]
# ### Create GeoDataFrame with Polygons

# %%
gdf = gg.post.extract_lithologies(geo_model, geo_data.extent[:4], geo_data.crs)
gdf
# Out:
#   formation                                           geometry
# 0  basement  POLYGON ((5.107 499.515, 5.832 500.296, 8.624 ...
# 1  basement  POLYGON ((822.312 568.537, 826.200 567.934, 83...
# 2       Ton  POLYGON ((837.864 164.929, 841.752 164.696, 84...
# 3     Sand1  POLYGON ((5.832 1.944, 9.720 1.944, 13.608 1.9...

# %% [markdown]
# ### Plot Polygons

# %%
gdf.plot(column='formation', cmap=ListedColormap(cols), alpha=0.9, aspect='equal')
plt.grid()

# %% [markdown]
# ### Save Polygons as Shape Files
#
# These polygons can now be saved as shape files and displayed for example as in QGIS shown below.

# %%
gdf.to_file('../../../../gemgis_data/data/example01_parallel_inclined_layers/liths.shp')

# %% [markdown]
# ### Save Polygons as GeoTiff
#
# Rasters like DEMs can be saved as georeferenced tif-files. The same can be done with the geological map obtained from `GemPy` by saving the array of the geological map as tif.

# %% [raw]
# gg.raster.save_as_tiff(raster=gmap, path='../../../../gemgis_data/data/example01_parallel_inclined_layers/geolmap.tif',extent=geo_data.extent, crs='EPSG:4326')

# %% [markdown]
# ## Create borehole from Geo_Model
#
# Geological models are used to extract information from the subsurface. As geologists, we like to look of the result of the model at a single location and down to the maximum z extent in depth. This is termed a borehole or in the case of fluid extraction a well. These boreholes can easily be extracted and displayed using GemGIS. All you need is the `geo_model` object, the `geo_data` object and the location of your borehole, optionally with its maximum depth.

# %%
sol, well_model, depth_dict = gg.post.extract_borehole(geo_model, geo_data, [500,500])
# Out:
# Active grids: ['regular']
# Compiling theano function...
# Level of Optimization:  fast_run
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                   values
# range            500.20
# $C_o$           5957.14
# drift equations     [3]

# %%
depth_dict
# Out:
# {1: 440.0, 2: 380.0, 3: 300.0}

# %% [markdown]
# ## Depth Maps
#
# Depth maps indicate the depth of a surface within the model extent. By applying an intuitive color coding, the spatial position of the respective surface can easily be interpreted. Depth maps can easily be created by executing `gg.visualization.plot_depth_map(...)`. All that is needed is the `geo_model` object and the name of the surface to be plotted. Optionally, a range for the colorbar can be provided to make the maps of different surfaces comparable. Otherwise, the min and max values of each surface are taken for the limits of the color bar. By setting `notebook` to `False` an interactive PyVista Window is opened (press 'Q' to close window safely again).

# %% [markdown]
# ### Depth Map Sand1

# %%
map1 = gg.visualization.create_depth_maps_from_gempy(geo_model=geo_model,
                                                     surfaces='Sand1')

# %% [markdown]
# ### Depth Map Ton

# %%
map2 = gg.visualization.create_depth_maps_from_gempy(geo_model=geo_model,
                                                     surfaces='Ton')

# %% [markdown]
# ### Plotting the Maps

# %%
import pyvista as pv 

p = pv.Plotter(notebook=True)

p.add_mesh(map1['Sand1'][0], scalars = 'Depth [m]')
p.add_mesh(map2['Ton'][0], scalars = 'Depth [m]')

p.set_background('white')
p.show_grid(color='black')
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x25C68C5BCA0>
